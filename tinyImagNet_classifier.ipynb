# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaunakNandi/training-from-scratch/blob/master/tinyImagNet_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Project Summary*:
#
# 1. Spatially seperated conv2D on RESNET18 (24M params). Model draws inspiration from DenseNet to maintain the perspective of the input image itself at each and every concatenation
#
# 2. Removed dense layer
#
# 3. Image Aug implemented (8 parameters where batch_norm is implemented in model itself)
#
# 4. Implemented Cyclic LR
#
# 5. Max val acc: 53.56% (Epoch 105)

# %%
# https://keras.io/
# !pip install -q keras
import keras

from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils

from keras.layers import Activation,AveragePooling2D,BatchNormalization,Concatenate,Conv2D,Flatten,GlobalAveragePooling2D,Lambda,MaxPooling2D
from keras.layers.merge import concatenate
from keras.models import Model,Input
from keras.optimizers import Adam

from keras.callbacks import LearningRateScheduler, ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from math import ceil
import os

import numpy as np

# this part will prevent tensorflow to allocate all the avaliable GPU Memory
# backend
import tensorflow as tf
from keras import backend as k

# Don't pre-allocate memory; allocate as-needed
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# Create a session with the above options specified.
k.tensorflow_backend.set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #Run on system restarts (next two code blocks)
#
# once is sufficient

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
#unzip model
# !unzip '/content/gdrive/My Drive/models/res22/res22.zip'
# Out:
# Archive:  /content/gdrive/My Drive/models/res22/res22.zip
#   inflating: res22.h5

# %%
#self made validation dataset (LABELLED)
# !unzip '/content/gdrive/My Drive/tiny-imagenet-200_with_val_labels.zip'

# %%
def space_to_depth_x2(x):
    return tf.space_to_depth(x, block_size=2)

# %% [markdown]
# #ResNet18

# %%
#RESNET 18 ARCHITECTURE
#NOT residual yet.. trying to get entire code running
nb_classes=200 #trying with 10 classes first
img_height, img_width, channels = None, None, 3 #32,32,3#64,64,3

input = Input(shape=(img_height, img_width, channels,), name='input') 

#BLOCK1
Layer0a = Conv2D(64, (8,1), strides=(2,1), padding='same', name='conv1a', use_bias=False)(input)  #32,32,32
Layer0b = Conv2D(64, (1,8), strides=(1,2), padding='same', name='conv1b', use_bias=False)(Layer0a)  #32,32,32
Layer0 = BatchNormalization(name='norm1')(Layer0b)
Layer0 = Activation('relu')(Layer0)

#Layer0 = MaxPooling2D(pool_size=(3,3), strides=(1,1))(Layer0)
skip_connection = Layer0

#BLOCK 2a
# Layer 1 
Layer1a = Conv2D(64, (3,1), strides=(1,1), padding='same', name='conv2_1a', use_bias=False)(Layer0)  #32,32,32
Layer1b = Conv2D(64, (1,3), strides=(1,1), padding='same', name='conv2_1b', use_bias=False)(Layer1a)  #32,32,32
Layer1 = BatchNormalization(name='norm2_1')(Layer1b)
Layer1 = Activation('relu')(Layer1)
# Layer 2
Layer2a = Conv2D(64, (3,1), strides=(1,1), padding='same', name='conv2_2a', use_bias=False)(Layer1) #32,32,64
Layer2b = Conv2D(64, (1,3), strides=(1,1), padding='same', name='conv2_2b', use_bias=False)(Layer2a) #32,32,64
Layer2 = BatchNormalization(name='norm2_2')(Layer2b)
Layer2 = Activation('relu')(Layer2)

skip_connection = Conv2D(64, (1,1), strides=(1,1), padding='valid', use_bias=False)(skip_connection)
skip_connection = BatchNormalization()(skip_connection)
skip_connection = Activation('relu')(skip_connection)
Layer2 = concatenate([skip_connection, Layer2])
skip_connection = Layer2

#BLOCK 2b
# Layer 3
Layer3a = Conv2D(64, (3,1), strides=(1,1), padding='same', name='conv2_3', use_bias=False)(Layer2) #32,32,128
Layer3b = Conv2D(64, (1,3), strides=(1,1), padding='same', name='conv2_3b', use_bias=False)(Layer3a) #32,32,128
Layer3 = BatchNormalization(name='norm2_3')(Layer3b)
Layer3 = Activation('relu')(Layer3)
# Layer 4
Layer4a = Conv2D(64, (3,1), strides=(1,1), padding='same', name='conv2_4a', use_bias=False)(Layer3)  #32,32,32
Layer4b = Conv2D(64, (1,3), strides=(1,1), padding='same', name='conv2_4b', use_bias=False)(Layer4a)  #32,32,32
Layer4 = BatchNormalization(name='norm2_4')(Layer4b)
Layer4 = Activation('relu')(Layer4)

skip_connection = Conv2D(64, (1,1), strides=(1,1), padding='valid', use_bias=False)(skip_connection)
skip_connection = BatchNormalization()(skip_connection)
skip_connection = Activation('relu')(skip_connection)
Layer4 = concatenate([skip_connection, Layer4, Layer0])

#BLOCK 3a
# Layer 5
Layer5a = Conv2D(128, (3,1), strides=(2,1), padding='same', name='conv2_7a', use_bias=False)(Layer4)  #32,32,32
Layer5b = Conv2D(128, (1,3), strides=(1,2), padding='same', name='conv2_7b', use_bias=False)(Layer5a)
Layer5 = BatchNormalization(name='norm2_7')(Layer5b)
Layer5 = Activation('relu')(Layer5)
# Layer 6
Layer6a = Conv2D(128, (3,1), strides=(1,1), padding='same', name='conv2_8a', use_bias=False)(Layer5) #32,32,64
Layer6b = Conv2D(128, (1,3), strides=(1,1), padding='same', name='conv2_8b', use_bias=False)(Layer6a)
Layer6 = BatchNormalization(name='norm2_8')(Layer6b)
Layer6 = Activation('relu')(Layer6)

skip_connection = Layer6

#BLOCK 3b
# Layer 7
Layer7a = Conv2D(128, (3,1), strides=(1,1), padding='same', name='conv2_9a', use_bias=False)(Layer6) #32,32,128
Layer7b = Conv2D(128, (1,3), strides=(1,1), padding='same', name='conv2_9b', use_bias=False)(Layer7a)
Layer7 = BatchNormalization(name='norm2_9')(Layer7b)
Layer7 = Activation('relu')(Layer7)
# Layer 8
Layer8a = Conv2D(128, (3,1), strides=(1,1), padding='same', name='conv3_1a', use_bias=False)(Layer7)  #32,32,32
Layer8b = Conv2D(128, (1,3), strides=(1,1), padding='same', name='conv3_1b', use_bias=False)(Layer8a)
Layer8 = BatchNormalization(name='norm3_1')(Layer8b)
Layer8 = Activation('relu')(Layer8)

skip_connection = Conv2D(128, (1,1), strides=(1,1), padding='valid', use_bias=False)(skip_connection)
skip_connection = BatchNormalization()(skip_connection)
skip_connection = Activation('relu')(skip_connection)

forLayer8 = Layer0
forLayer8  = MaxPooling2D(pool_size=(2,2), strides=(2,2))(Layer0)
#forLayer8 = space_to_depth_x2(forLayer8)
print(forLayer8.shape)
Layer8 = concatenate([skip_connection, Layer8, forLayer8])
skip_connection = Layer8

#BLOCK 4a
# Layer 9
Layer9a = Conv2D(256, (3,1), strides=(2,1), padding='same', name='conv3_6a', use_bias=False)(Layer8) #32,32,128
Layer9b = Conv2D(256, (1,3), strides=(1,2), padding='same', name='conv3_6b', use_bias=False)(Layer9a)
Layer9 = BatchNormalization(name='norm3_6')(Layer9b)
Layer9 = Activation('relu')(Layer9)
# Layer 10
Layer10a = Conv2D(256, (3,1), strides=(1,1), padding='same', name='conv3_7a', use_bias=False)(Layer9)  #32,32,32
Layer10b = Conv2D(256, (1,3), strides=(1,1), padding='same', name='conv3_7b', use_bias=False)(Layer10a)
Layer10 = BatchNormalization(name='norm3_7')(Layer10b)
Layer10 = Activation('relu')(Layer10)

skip_connection = Layer10

#BLOCK 4b
# Layer 11
Layer11a = Conv2D(256, (3,1), strides=(1,1), padding='same', name='conv3_8a', use_bias=False)(Layer10) #32,32,64
Layer11b = Conv2D(256, (1,3), strides=(1,1), padding='same', name='conv3_8b', use_bias=False)(Layer11a)
Layer11 = BatchNormalization(name='norm3_8')(Layer11b)
Layer11 = Activation('relu')(Layer11)
# Layer 12
Layer12a = Conv2D(256, (3,1), strides=(1,1), padding='same', name='conv3_9a', use_bias=False)(Layer11) #32,32,128
Layer12b = Conv2D(256, (1,3), strides=(1,1), padding='same', name='conv3_9b', use_bias=False)(Layer12a)
Layer12 = BatchNormalization(name='norm3_9')(Layer12b)
Layer12 = Activation('relu')(Layer12)

forLayer12 = forLayer8
forLayer12 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(Layer8)
skip_connection = Conv2D(256, (1,1), strides=(1,1), padding='valid', use_bias=False)(skip_connection)
skip_connection = BatchNormalization()(skip_connection)
skip_connection = Activation('relu')(skip_connection)
Layer12 = concatenate([skip_connection, Layer12, forLayer12])


#BLOCK 5a
# Layer 13
Layer13a = Conv2D(512, (3,1), strides=(2,1), padding='same', name='conv4_9a', use_bias=False)(Layer12) #32,32,128
Layer13b = Conv2D(512, (1,3), strides=(1,2), padding='same', name='conv4_9b', use_bias=False)(Layer13a)
Layer13 = BatchNormalization(name='norm4_9')(Layer13b)
Layer13 = Activation('relu')(Layer13)
# Layer 14
Layer14a = Conv2D(512, (3,1), strides=(1,1), padding='same', name='conv4_10a', use_bias=False)(Layer13) #32,32,128
Layer14b = Conv2D(512, (1,3), strides=(1,1), padding='same', name='conv4_10b', use_bias=False)(Layer14a)
Layer14 = BatchNormalization(name='norm4_10')(Layer14b)
Layer14 = Activation('relu')(Layer14)

skip_connection = Layer14

#BLOCK 5b
# Layer 15
Layer15a = Conv2D(512, (3,1), strides=(1,1), padding='same', name='conv4_11a', use_bias=False)(Layer14) #32,32,128
Layer15b = Conv2D(512, (1,3), strides=(1,1), padding='same', name='conv4_11b', use_bias=False)(Layer15a)
Layer15 = BatchNormalization(name='norm4_11')(Layer15b)
Layer15 = Activation('relu')(Layer15)
# Layer 16
Layer16a = Conv2D(512, (3,1), strides=(1,1), padding='same', name='conv4_12a', use_bias=False)(Layer15) #32,32,128
Layer16b = Conv2D(512, (1,3), strides=(1,1), padding='same', name='conv4_12b', use_bias=False)(Layer16a)
Layer16 = BatchNormalization(name='norm4_12')(Layer16b)
Layer16 = Activation('relu')(Layer16)

forLayer16 = forLayer12
forLayer16 = MaxPooling2D(pool_size=(2,2), strides=(2,2))(Layer12)
skip_connection = Conv2D(512, (1,1), strides=(1,1), padding='valid', use_bias=False)(skip_connection)
skip_connection = BatchNormalization()(skip_connection)
skip_connection = Activation('relu')(skip_connection)
Layer16 = concatenate([skip_connection, Layer16, forLayer16])

#BLOCK 6a
# Layer 15
Layer17a = Conv2D(1024, (3,1), strides=(1,1), padding='same', name='conv5_13a', use_bias=False)(Layer16) #32,32,128
Layer17b = Conv2D(1024, (1,3), strides=(1,1), padding='same', name='conv5_13b', use_bias=False)(Layer17a)
Layer17 = BatchNormalization(name='norm5_13')(Layer17b)
Layer17 = Activation('relu')(Layer17)

# Layer 16
Layer18a = Conv2D(1024, (3,1), strides=(1,1), padding='same', name='conv5_14a', use_bias=False)(Layer17) #32,32,128
Layer18b = Conv2D(1024, (1,3), strides=(1,1), padding='same', name='conv5_14b', use_bias=False)(Layer18a)
Layer18 = BatchNormalization(name='norm5_14')(Layer18b)
Layer18 = Activation('relu')(Layer18)


Layer21 = Conv2D(200, (1,1), strides=(1,1), padding='valid', use_bias=False)(Layer18)
print('layer21: ', Layer21.shape)
output = GlobalAveragePooling2D(data_format='channels_last', name='output')(Layer21)
output = Activation('softmax')(output)
print('output: ', output.shape)
print(output.shape)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# (?, ?, ?, 64)
# layer21:  (?, ?, ?, 200)
# output:  (?, 200)
# (?, 200)

# %% [markdown]
# #Model Summary

# %%
model = Model(inputs=[input], outputs=[output])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1a (Conv2D)                 (None, None, None, 6 1536        input[0][0]
# __________________________________________________________________________________________________
# conv1b (Conv2D)                 (None, None, None, 6 32768       conv1a[0][0]
# __________________________________________________________________________________________________
# norm1 (BatchNormalization)      (None, None, None, 6 256         conv1b[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           norm1[0][0]
# __________________________________________________________________________________________________
# conv2_1a (Conv2D)               (None, None, None, 6 12288       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2_1b (Conv2D)               (None, None, None, 6 12288       conv2_1a[0][0]
# __________________________________________________________________________________________________
# norm2_1 (BatchNormalization)    (None, None, None, 6 256         conv2_1b[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           norm2_1[0][0]
# __________________________________________________________________________________________________
# conv2_2a (Conv2D)               (None, None, None, 6 12288       activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 6 4096        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2_2b (Conv2D)               (None, None, None, 6 12288       conv2_2a[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 6 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# norm2_2 (BatchNormalization)    (None, None, None, 6 256         conv2_2b[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 6 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           norm2_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 1 0           activation_4[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2_3 (Conv2D)                (None, None, None, 6 24576       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2_3b (Conv2D)               (None, None, None, 6 12288       conv2_3[0][0]
# __________________________________________________________________________________________________
# norm2_3 (BatchNormalization)    (None, None, None, 6 256         conv2_3b[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           norm2_3[0][0]
# __________________________________________________________________________________________________
# conv2_4a (Conv2D)               (None, None, None, 6 12288       activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 6 8192        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2_4b (Conv2D)               (None, None, None, 6 12288       conv2_4a[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 6 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# norm2_4 (BatchNormalization)    (None, None, None, 6 256         conv2_4b[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           norm2_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 1 0           activation_7[0][0]
#                                                                  activation_6[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2_7a (Conv2D)               (None, None, None, 1 73728       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2_7b (Conv2D)               (None, None, None, 1 49152       conv2_7a[0][0]
# __________________________________________________________________________________________________
# norm2_7 (BatchNormalization)    (None, None, None, 1 512         conv2_7b[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 1 0           norm2_7[0][0]
# __________________________________________________________________________________________________
# conv2_8a (Conv2D)               (None, None, None, 1 49152       activation_8[0][0]
# __________________________________________________________________________________________________
# conv2_8b (Conv2D)               (None, None, None, 1 49152       conv2_8a[0][0]
# __________________________________________________________________________________________________
# norm2_8 (BatchNormalization)    (None, None, None, 1 512         conv2_8b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 1 0           norm2_8[0][0]
# __________________________________________________________________________________________________
# conv2_9a (Conv2D)               (None, None, None, 1 49152       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2_9b (Conv2D)               (None, None, None, 1 49152       conv2_9a[0][0]
# __________________________________________________________________________________________________
# norm2_9 (BatchNormalization)    (None, None, None, 1 512         conv2_9b[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 1 0           norm2_9[0][0]
# __________________________________________________________________________________________________
# conv3_1a (Conv2D)               (None, None, None, 1 49152       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 1 16384       activation_9[0][0]
# __________________________________________________________________________________________________
# conv3_1b (Conv2D)               (None, None, None, 1 49152       conv3_1a[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 1 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# norm3_1 (BatchNormalization)    (None, None, None, 1 512         conv3_1b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           norm3_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 3 0           activation_12[0][0]
#                                                                  activation_11[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv3_6a (Conv2D)               (None, None, None, 2 245760      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv3_6b (Conv2D)               (None, None, None, 2 196608      conv3_6a[0][0]
# __________________________________________________________________________________________________
# norm3_6 (BatchNormalization)    (None, None, None, 2 1024        conv3_6b[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 2 0           norm3_6[0][0]
# __________________________________________________________________________________________________
# conv3_7a (Conv2D)               (None, None, None, 2 196608      activation_13[0][0]
# __________________________________________________________________________________________________
# conv3_7b (Conv2D)               (None, None, None, 2 196608      conv3_7a[0][0]
# __________________________________________________________________________________________________
# norm3_7 (BatchNormalization)    (None, None, None, 2 1024        conv3_7b[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 2 0           norm3_7[0][0]
# __________________________________________________________________________________________________
# conv3_8a (Conv2D)               (None, None, None, 2 196608      activation_14[0][0]
# __________________________________________________________________________________________________
# conv3_8b (Conv2D)               (None, None, None, 2 196608      conv3_8a[0][0]
# __________________________________________________________________________________________________
# norm3_8 (BatchNormalization)    (None, None, None, 2 1024        conv3_8b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 2 0           norm3_8[0][0]
# __________________________________________________________________________________________________
# conv3_9a (Conv2D)               (None, None, None, 2 196608      activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 2 65536       activation_14[0][0]
# __________________________________________________________________________________________________
# conv3_9b (Conv2D)               (None, None, None, 2 196608      conv3_9a[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 2 1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# norm3_9 (BatchNormalization)    (None, None, None, 2 1024        conv3_9b[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 2 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 2 0           norm3_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 3 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, None, None, 8 0           activation_17[0][0]
#                                                                  activation_16[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv4_9a (Conv2D)               (None, None, None, 5 1277952     concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv4_9b (Conv2D)               (None, None, None, 5 786432      conv4_9a[0][0]
# __________________________________________________________________________________________________
# norm4_9 (BatchNormalization)    (None, None, None, 5 2048        conv4_9b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 5 0           norm4_9[0][0]
# __________________________________________________________________________________________________
# conv4_10a (Conv2D)              (None, None, None, 5 786432      activation_18[0][0]
# __________________________________________________________________________________________________
# conv4_10b (Conv2D)              (None, None, None, 5 786432      conv4_10a[0][0]
# __________________________________________________________________________________________________
# norm4_10 (BatchNormalization)   (None, None, None, 5 2048        conv4_10b[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           norm4_10[0][0]
# __________________________________________________________________________________________________
# conv4_11a (Conv2D)              (None, None, None, 5 786432      activation_19[0][0]
# __________________________________________________________________________________________________
# conv4_11b (Conv2D)              (None, None, None, 5 786432      conv4_11a[0][0]
# __________________________________________________________________________________________________
# norm4_11 (BatchNormalization)   (None, None, None, 5 2048        conv4_11b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 5 0           norm4_11[0][0]
# __________________________________________________________________________________________________
# conv4_12a (Conv2D)              (None, None, None, 5 786432      activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 5 262144      activation_19[0][0]
# __________________________________________________________________________________________________
# conv4_12b (Conv2D)              (None, None, None, 5 786432      conv4_12a[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 5 2048        conv2d_5[0][0]
# __________________________________________________________________________________________________
# norm4_12 (BatchNormalization)   (None, None, None, 5 2048        conv4_12b[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 5 0           norm4_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 8 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, None, None, 1 0           activation_22[0][0]
#                                                                  activation_21[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv5_13a (Conv2D)              (None, None, None, 1 5701632     concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv5_13b (Conv2D)              (None, None, None, 1 3145728     conv5_13a[0][0]
# __________________________________________________________________________________________________
# norm5_13 (BatchNormalization)   (None, None, None, 1 4096        conv5_13b[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 1 0           norm5_13[0][0]
# __________________________________________________________________________________________________
# conv5_14a (Conv2D)              (None, None, None, 1 3145728     activation_23[0][0]
# __________________________________________________________________________________________________
# conv5_14b (Conv2D)              (None, None, None, 1 3145728     conv5_14a[0][0]
# __________________________________________________________________________________________________
# norm5_14 (BatchNormalization)   (None, None, None, 1 4096        conv5_14b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 1 0           norm5_14[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 2 204800      activation_24[0][0]
# __________________________________________________________________________________________________
# output (GlobalAveragePooling2D) (None, 200)          0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 200)          0           output[0][0]
# ==================================================================================================
# Total params: 24,695,552
# Trainable params: 24,681,600
# Non-trainable params: 13,952
# __________________________________________________________________________________________________

# %% [markdown]
# #Optimizer : Adam

# %%
'''
def get_lr_metric(optimizer):
  def lr(y_true, y_pred):
    return optimizer.lr
  return lr

optimizer = Adam(lr=0.01)
lr_metric = get_lr_metric(optimizer)
'''

model.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              # Nadam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=None, schedule_decay=0.004)
              metrics = ['accuracy'])

# %% [markdown]
# #Run model (epoch 1 - 15)

# %%
'''
print('loading model')
from keras.models import load_model
model = load_model('/content/gdrive/My Drive/models/res22/res22mod.h5')
print('model loaded')
'''

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=3, min_lr=0.00099)
checkpoints = ModelCheckpoint(filepath='/content/gdrive/My Drive/models/res22/res22mod.h5', 
                               verbose=1,
                               save_weights_only=False,
                               save_best_only=True)

datagen = ImageDataGenerator(
        rescale=0
        #shear_range=0.2,
        #zca_whitening=True,
        #featurewise_center=True,
        #samplewise_center=True,
        #zoom_range=0.2,
        #horizontal_flip=True,
        #rotation_range=10,
        #width_shift_range=0.2,
        #height_shift_range=0.2
        )

train_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/train',
        target_size=(32,32),
        batch_size=256,
        class_mode='categorical')

validation_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/VAL_SELF',
        target_size=(64,64),
        batch_size=32,
        class_mode='categorical')

model.fit_generator(
        train_generator,
        steps_per_epoch=100000 // 256,
        epochs=15,
        #initial_epoch=0,
        callbacks=[reduce_lr, checkpoints],
        validation_data=validation_generator,
        validation_steps=10000//32)

model.save('res22mod.h5')
model.save('/content/gdrive/My Drive/models/res22/res22mod.h5')
print('model saved')
# Out:
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/15
# 390/390 [==============================] - 183s 470ms/step - loss: 4.7694 - acc: 0.0444 - val_loss: 7.1340 - val_acc: 0.0227
#
# Epoch 00001: val_loss improved from inf to 7.13404, saving model to /content/gdrive/My Drive/models/res22/res22mod.h5
# Epoch 2/15
# 390/390 [==============================] - 171s 437ms/step - loss: 4.0884 - acc: 0.1149 - val_loss: 7.0365 - val_acc: 0.0465
#
# Epoch 00002: val_loss improved from 7.13404 to 7.03651, saving model to /content/gdrive/My Drive/models/res22/res22mod.h5
# Epoch 3/15
# 390/390 [==============================] - 167s 429ms/step - loss: 3.6742 - acc: 0.1755 - val_loss: 5.9976 - val_acc: 0.0662
#
# Epoch 00003: val_loss improved from 7.03651 to 5.99761, saving model to /content/gdrive/My Drive/models/res22/res22mod.h5
# Epoch 4/15
# 390/390 [==============================] - 169s 434ms/step - loss: 3.4087 - acc: 0.2176 - val_loss: 6.2669 - val_acc: 0.0522
#
# Epoch 00004: val_loss did not improve from 5.99761
# Epoch 5/15
# 390/390 [==============================] - 168s 431ms/step - loss: 3.2097 - acc: 0.2526 - val_loss: 5.3416 - val_acc: 0.0735
#
# Epoch 00005: val_loss improved from 5.99761 to 5.34164, saving model to /content/gdrive/My Drive/models/res22/res22mod.h5
# Epoch 6/15
# 390/390 [==============================] - 169s 433ms/step - loss: 3.0239 - acc: 0.2841 - val_loss: 5.4006 - val_acc: 0.0869
#
# Epoch 00006: val_loss did not improve from 5.34164
# Epoch 7/15
# 390/390 [==============================] - 169s 432ms/step - loss: 2.8659 - acc: 0.3149 - val_loss: 4.9825 - val_acc: 0.1046
#
# Epoch 00007: val_loss improved from 5.34164 to 4.98249, saving model to /content/gdrive/My Drive/models/res22/res22mod.h5
# Epoch 8/15
# 390/390 [==============================] - 169s 432ms/step - loss: 2.7159 - acc: 0.3441 - val_loss: 5.0475 - val_acc: 0.0999
#
# Epoch 00008: val_loss did not improve from 4.98249
# Epoch 9/15
# 390/390 [==============================] - 169s 432ms/step - loss: 2.5724 - acc: 0.3699 - val_loss: 5.7260 - val_acc: 0.0844
#
# Epoch 00009: val_loss did not improve from 4.98249
# Epoch 10/15
# 390/390 [==============================] - 168s 432ms/step - loss: 2.4308 - acc: 0.3963 - val_loss: 5.8195 - val_acc: 0.0777
#
# Epoch 00010: val_loss did not improve from 4.98249
# Epoch 11/15
# 390/390 [==============================] - 168s 431ms/step - loss: 2.2733 - acc: 0.4268 - val_loss: 5.3201 - val_acc: 0.0874
#
# Epoch 00011: val_loss did not improve from 4.98249
# Epoch 12/15
# 390/390 [==============================] - 168s 431ms/step - loss: 2.1188 - acc: 0.4569 - val_loss: 6.5844 - val_acc: 0.0683
#
# Epoch 00012: val_loss did not improve from 4.98249
# Epoch 13/15
# 390/390 [==============================] - 168s 431ms/step - loss: 1.9711 - acc: 0.4883 - val_loss: 7.0498 - val_acc: 0.0729
#
# Epoch 00013: val_loss did not improve from 4.98249
# Epoch 14/15
# 390/390 [==============================] - 168s 430ms/step - loss: 1.8166 - acc: 0.5210 - val_loss: 7.2716 - val_acc: 0.0752
#
# Epoch 00014: val_loss did not improve from 4.98249
# Epoch 15/15
# 390/390 [==============================] - 168s 431ms/step - loss: 1.6532 - acc: 0.5573 - val_loss: 7.8584 - val_acc: 0.0758
#
# Epoch 00015: val_loss did not improve from 4.98249
# model saved

# %% [markdown]
# #Epoch 16 - 20

# %%
print('loading model')
from keras.models import load_model
model = load_model('/content/gdrive/My Drive/models/res22/res22mod.h5')
print('model loaded')

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=3, min_lr=0.00099)
checkpoints = ModelCheckpoint(filepath='/content/gdrive/My Drive/models/res22/res22mod.h5', 
                               verbose=1,
                               save_weights_only=False,
                               save_best_only=True)

datagen = ImageDataGenerator(
        rescale=0
        #shear_range=0.2,
        #zca_whitening=True,
        #featurewise_center=True,
        #samplewise_center=True,
        #zoom_range=0.2,
        #horizontal_flip=True,
        #rotation_range=10,
        #width_shift_range=0.2,
        #height_shift_range=0.2
        )

train_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/train',
        target_size=(16,16),
        batch_size=256,
        class_mode='categorical')

validation_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/VAL_SELF',
        target_size=(64,64),
        batch_size=32,
        class_mode='categorical')

model.fit_generator(
        train_generator,
        steps_per_epoch=100000 // 256,
        epochs=5,
        #initial_epoch=0,
        callbacks=[reduce_lr, checkpoints],
        validation_data=validation_generator,
        validation_steps=10000//32)

model.save('res22mod.h5')
model.save('/content/gdrive/My Drive/models/res22/res22mod.h5')
print('model saved')
# Out:
# loading model
# model loaded
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# Epoch 1/5
# 390/390 [==============================] - 152s 391ms/step - loss: 3.7835 - acc: 0.1810 - val_loss: 15.3649 - val_acc: 0.0184
#
# Epoch 00001: val_loss improved from inf to 15.36488, saving model to /content/gdrive/My Drive/models/res22/res22mod.h5
# Epoch 2/5
# 390/390 [==============================] - 145s 372ms/step - loss: 3.2699 - acc: 0.2520 - val_loss: 14.9575 - val_acc: 0.0218
#
# Epoch 00002: val_loss improved from 15.36488 to 14.95753, saving model to /content/gdrive/My Drive/models/res22/res22mod.h5
# Epoch 3/5
# 390/390 [==============================] - 143s 367ms/step - loss: 3.0604 - acc: 0.2857 - val_loss: 14.7667 - val_acc: 0.0320
#
# Epoch 00003: val_loss improved from 14.95753 to 14.76666, saving model to /content/gdrive/My Drive/models/res22/res22mod.h5
# Epoch 4/5
# 390/390 [==============================] - 143s 368ms/step - loss: 2.8973 - acc: 0.3142 - val_loss: 15.4063 - val_acc: 0.0195
#
# Epoch 00004: val_loss did not improve from 14.76666
# Epoch 5/5
# 390/390 [==============================] - 143s 366ms/step - loss: 2.7517 - acc: 0.3396 - val_loss: 15.3108 - val_acc: 0.0162
#
# Epoch 00005: val_loss did not improve from 14.76666
# model saved

# %% [markdown]
# #Epoch 21 - 50

# %%
print('loading model')
from keras.models import load_model
model = load_model('/content/gdrive/My Drive/models/res22/res22mod.h5')
print('model loaded')

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=3, min_lr=0.00099)
checkpoints = ModelCheckpoint(filepath='/content/gdrive/My Drive/models/res22/res22mod.h5', 
                               verbose=1,
                               save_weights_only=False,
                               save_best_only=True)

datagen = ImageDataGenerator(
        rescale=0
        #shear_range=0.2,
        #zca_whitening=True,
        #featurewise_center=True,
        #samplewise_center=True,
        #zoom_range=0.2,
        #horizontal_flip=True,
        #rotation_range=10,
        #width_shift_range=0.2,
        #height_shift_range=0.2
        )

train_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/train',
        target_size=(64,64),
        batch_size=256,
        class_mode='categorical')

validation_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/VAL_SELF',
        target_size=(64,64),
        batch_size=32,
        class_mode='categorical')

model.fit_generator(
        train_generator,
        steps_per_epoch=100000 // 256,
        epochs=30,
        #initial_epoch=0,
        callbacks=[reduce_lr, checkpoints],
        validation_data=validation_generator,
        validation_steps=10000//32)

model.save('res22mod.h5')
model.save('/content/gdrive/My Drive/models/res22/res22mod.h5')
print('model saved')
# Out:
# loading model
# model loaded
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# Epoch 1/30
# 390/390 [==============================] - 458s 1s/step - loss: 2.7156 - acc: 0.3476 - val_loss: 2.7851 - val_acc: 0.3399
#
# Epoch 00001: val_loss improved from inf to 2.78509, saving model to /content/gdrive/My Drive/models/res22/res22mod.h5
# Epoch 2/30
# 390/390 [==============================] - 448s 1s/step - loss: 2.2855 - acc: 0.4316 - val_loss: 2.6900 - val_acc: 0.3573
#
# Epoch 00002: val_loss improved from 2.78509 to 2.68999, saving model to /content/gdrive/My Drive/models/res22/res22mod.h5
# Epoch 3/30
# 390/390 [==============================] - 444s 1s/step - loss: 2.0822 - acc: 0.4746 - val_loss: 2.7361 - val_acc: 0.3647
#
# Epoch 00003: val_loss did not improve from 2.68999
# Epoch 4/30
# 390/390 [==============================] - 444s 1s/step - loss: 1.9131 - acc: 0.5092 - val_loss: 2.8453 - val_acc: 0.3504
#
# Epoch 00004: val_loss did not improve from 2.68999
# Epoch 5/30
# 390/390 [==============================] - 444s 1s/step - loss: 1.7484 - acc: 0.5442 - val_loss: 2.7917 - val_acc: 0.3657
#
# Epoch 00005: val_loss did not improve from 2.68999
# Epoch 6/30
# 390/390 [==============================] - 444s 1s/step - loss: 1.5898 - acc: 0.5798 - val_loss: 3.1529 - val_acc: 0.3294
#
# Epoch 00006: val_loss did not improve from 2.68999
# Epoch 7/30
# 390/390 [==============================] - 444s 1s/step - loss: 1.4324 - acc: 0.6142 - val_loss: 3.0687 - val_acc: 0.3671
#
# Epoch 00007: val_loss did not improve from 2.68999
# Epoch 8/30
# 390/390 [==============================] - 444s 1s/step - loss: 1.2605 - acc: 0.6559 - val_loss: 3.2448 - val_acc: 0.3471
#
# Epoch 00008: val_loss did not improve from 2.68999
# Epoch 9/30
# 390/390 [==============================] - 444s 1s/step - loss: 1.1073 - acc: 0.6922 - val_loss: 3.1909 - val_acc: 0.3525
#
# Epoch 00009: val_loss did not improve from 2.68999
# Epoch 10/30
# 390/390 [==============================] - 444s 1s/step - loss: 0.9408 - acc: 0.7349 - val_loss: 3.1945 - val_acc: 0.3721
#
# Epoch 00010: val_loss did not improve from 2.68999
# Epoch 11/30
# 390/390 [==============================] - 444s 1s/step - loss: 0.7926 - acc: 0.7726 - val_loss: 3.5408 - val_acc: 0.3544
#
# Epoch 00011: val_loss did not improve from 2.68999
# Epoch 12/30
# 390/390 [==============================] - 443s 1s/step - loss: 0.6625 - acc: 0.8058 - val_loss: 4.1350 - val_acc: 0.3298
#
# Epoch 00012: val_loss did not improve from 2.68999
# Epoch 13/30
# 390/390 [==============================] - 444s 1s/step - loss: 0.5600 - acc: 0.8349 - val_loss: 4.0390 - val_acc: 0.3511
#
# Epoch 00013: val_loss did not improve from 2.68999
# Epoch 14/30
# 390/390 [==============================] - 443s 1s/step - loss: 0.4561 - acc: 0.8644 - val_loss: 4.1236 - val_acc: 0.3350
#
# Epoch 00014: val_loss did not improve from 2.68999
# Epoch 15/30
# 390/390 [==============================] - 443s 1s/step - loss: 0.3887 - acc: 0.8825 - val_loss: 5.0150 - val_acc: 0.2956
#
# Epoch 00015: val_loss did not improve from 2.68999
# Epoch 16/30
# 390/390 [==============================] - 444s 1s/step - loss: 0.3406 - acc: 0.8954 - val_loss: 4.6508 - val_acc: 0.3250
#
# Epoch 00016: val_loss did not improve from 2.68999
# Epoch 17/30
# 390/390 [==============================] - 445s 1s/step - loss: 0.3090 - acc: 0.9042 - val_loss: 5.1458 - val_acc: 0.3216
#
# Epoch 00017: val_loss did not improve from 2.68999
# Epoch 18/30
# 390/390 [==============================] - 445s 1s/step - loss: 0.2889 - acc: 0.9105 - val_loss: 4.8999 - val_acc: 0.3310
#
# Epoch 00018: val_loss did not improve from 2.68999
# Epoch 19/30
# 390/390 [==============================] - 445s 1s/step - loss: 0.2384 - acc: 0.9267 - val_loss: 4.7312 - val_acc: 0.3361
#
# Epoch 00019: val_loss did not improve from 2.68999
# Epoch 20/30
# 390/390 [==============================] - 445s 1s/step - loss: 0.2244 - acc: 0.9300 - val_loss: 5.2504 - val_acc: 0.3112
#
# Epoch 00020: val_loss did not improve from 2.68999
# Epoch 21/30
# 390/390 [==============================] - 444s 1s/step - loss: 0.2431 - acc: 0.9213 - val_loss: 4.8175 - val_acc: 0.3434
#
# Epoch 00021: val_loss did not improve from 2.68999
# Epoch 22/30
# 390/390 [==============================] - 444s 1s/step - loss: 0.2084 - acc: 0.9342 - val_loss: 5.3512 - val_acc: 0.3127
#
# Epoch 00022: val_loss did not improve from 2.68999
# Epoch 23/30
# 390/390 [==============================] - 444s 1s/step - loss: 0.1805 - acc: 0.9432 - val_loss: 5.8741 - val_acc: 0.3099
#
# Epoch 00023: val_loss did not improve from 2.68999
# Epoch 24/30
# 390/390 [==============================] - 444s 1s/step - loss: 0.1920 - acc: 0.9387 - val_loss: 5.7099 - val_acc: 0.3182
#
# Epoch 00024: val_loss did not improve from 2.68999
# Epoch 25/30
# 390/390 [==============================] - 445s 1s/step - loss: 0.1968 - acc: 0.9368 - val_loss: 5.9891 - val_acc: 0.3181
#
# Epoch 00025: val_loss did not improve from 2.68999
# Epoch 26/30
# 390/390 [==============================] - 444s 1s/step - loss: 0.1704 - acc: 0.9459 - val_loss: 5.4752 - val_acc: 0.3451
#
# Epoch 00026: val_loss did not improve from 2.68999
# Epoch 27/30
# 390/390 [==============================] - 444s 1s/step - loss: 0.1500 - acc: 0.9530 - val_loss: 5.3970 - val_acc: 0.3244
#
# Epoch 00027: val_loss did not improve from 2.68999
# Epoch 28/30
# 390/390 [==============================] - 445s 1s/step - loss: 0.1661 - acc: 0.9464 - val_loss: 5.4751 - val_acc: 0.3256
#
# Epoch 00028: val_loss did not improve from 2.68999
# Epoch 29/30
# 390/390 [==============================] - 444s 1s/step - loss: 0.1623 - acc: 0.9473 - val_loss: 5.6905 - val_acc: 0.3234
#
# Epoch 00029: val_loss did not improve from 2.68999
# Epoch 30/30
# 390/390 [==============================] - 444s 1s/step - loss: 0.1446 - acc: 0.9537 - val_loss: 5.8557 - val_acc: 0.3262
#
# Epoch 00030: val_loss did not improve from 2.68999
# model saved

# %% [markdown]
# #Epoch 51 - 55 : Intro Image Aug

# %%
print('loading model')
from keras.models import load_model
model = load_model('/content/gdrive/My Drive/models/res22/res22mod.h5')
print('model loaded')

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=3, min_lr=0.00099)
checkpoints = ModelCheckpoint(filepath='/content/gdrive/My Drive/models/res22/res22mod_aug.h5', 
                               verbose=1,
                               save_weights_only=False,
                               save_best_only=True)

datagen = ImageDataGenerator(
        rescale=1./255,                      # 1. normalise pixel values to within 1. from 255.
        #shear_range=0.2,
        #zca_whitening=True,
        #featurewise_center=True,            
        #samplewise_center=True,             # did not find images to implement upon
        #featurewise_std_normalization=True, # 2. ignored by keras since it is already implemented
        #samplewise_std_normalization=True,  # ignored again
        zoom_range=0.2,                      # 3. 20% random zoom
        horizontal_flip=True,                # 4. easily double no. of images by flipping across Y axis
        rotation_range=10,                   # 5. random rotate by 10 deg
        width_shift_range=0.2,               # 6. remove 20% of img along X axis (possibly remove ROI)
        height_shift_range=0.2               # 7. remove 20% of img along Y axis (possibly remove ROI)
        #fill_mode='nearest'                 # 8. fill_mode introduced later (forgot about it early on)
        )

train_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/train',
        target_size=(64,64),
        batch_size=256,
        class_mode='categorical')

validation_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/VAL_SELF',
        target_size=(64,64),
        batch_size=32,
        class_mode='categorical')

model.fit_generator(
        train_generator,
        steps_per_epoch=100000 // 256,
        epochs=5,
        #initial_epoch=0,
        callbacks=[reduce_lr, checkpoints],
        validation_data=validation_generator,
        validation_steps=10000//32)

model.save('res22mod.h5')
model.save('/content/gdrive/My Drive/models/res22/res22mod_aug.h5')
print('model saved')
# Out:
# loading model
# model loaded
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# Epoch 1/5
# 390/390 [==============================] - 467s 1s/step - loss: 2.7722 - acc: 0.3812 - val_loss: 2.9848 - val_acc: 0.3375
#
# Epoch 00001: val_loss improved from inf to 2.98481, saving model to /content/gdrive/My Drive/models/res22/res22mod_aug.h5
# Epoch 2/5
# 390/390 [==============================] - 455s 1s/step - loss: 2.1994 - acc: 0.4543 - val_loss: 2.7114 - val_acc: 0.3763
#
# Epoch 00002: val_loss improved from 2.98481 to 2.71145, saving model to /content/gdrive/My Drive/models/res22/res22mod_aug.h5
# Epoch 3/5
# 390/390 [==============================] - 455s 1s/step - loss: 2.0652 - acc: 0.4793 - val_loss: 2.6585 - val_acc: 0.3910
#
# Epoch 00003: val_loss improved from 2.71145 to 2.65847, saving model to /content/gdrive/My Drive/models/res22/res22mod_aug.h5
# Epoch 4/5
# 390/390 [==============================] - 455s 1s/step - loss: 1.9787 - acc: 0.4983 - val_loss: 2.6337 - val_acc: 0.4016
#
# Epoch 00004: val_loss improved from 2.65847 to 2.63374, saving model to /content/gdrive/My Drive/models/res22/res22mod_aug.h5
# Epoch 5/5
# 297/390 [=====================>........] - ETA: 1:41 - loss: 1.8930 - acc: 0.5138

# %% [markdown]
# #Epoch 56 - 75

# %%
print('loading model')
from keras.models import load_model
model = load_model('/content/gdrive/My Drive/models/res22/res22mod_aug.h5')
print('model loaded')

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=3, min_lr=0.00099)
checkpoints = ModelCheckpoint(filepath='/content/gdrive/My Drive/models/res22/res22mod_aug.h5', 
                               verbose=1,
                               save_weights_only=False,
                               save_best_only=True)

datagen = ImageDataGenerator(
        rescale=1./255,
        #shear_range=0.2,
        #zca_whitening=True,
        #featurewise_center=True,
        #samplewise_center=True,
        zoom_range=0.2,
        horizontal_flip=True,
        rotation_range=10,
        width_shift_range=0.2,
        height_shift_range=0.2
        )

train_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/train',
        target_size=(64,64),
        batch_size=256,
        class_mode='categorical')

validation_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/VAL_SELF',
        target_size=(64,64),
        batch_size=32,
        class_mode='categorical')

model.fit_generator(
        train_generator,
        steps_per_epoch=100000 // 256,
        epochs=20,
        #initial_epoch=0,
        callbacks=[reduce_lr, checkpoints],
        validation_data=validation_generator,
        validation_steps=10000//32)

model.save('res22mod.h5')
model.save('/content/gdrive/My Drive/models/res22/res22mod_aug.h5')
print('model saved')
# Out:
# loading model
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# model loaded
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# Epoch 1/20
# 390/390 [==============================] - 507s 1s/step - loss: 1.9058 - acc: 0.5142 - val_loss: 2.8226 - val_acc: 0.3850
#
# Epoch 00001: val_loss improved from inf to 2.82262, saving model to /content/gdrive/My Drive/models/res22/res22mod_aug.h5
# Epoch 2/20
# 390/390 [==============================] - 494s 1s/step - loss: 1.8548 - acc: 0.5243 - val_loss: 2.6206 - val_acc: 0.4008
#
# Epoch 00002: val_loss improved from 2.82262 to 2.62061, saving model to /content/gdrive/My Drive/models/res22/res22mod_aug.h5
# Epoch 3/20
# 390/390 [==============================] - 487s 1s/step - loss: 1.7950 - acc: 0.5368 - val_loss: 2.7184 - val_acc: 0.3935
#
# Epoch 00003: val_loss did not improve from 2.62061
# Epoch 4/20
# 390/390 [==============================] - 486s 1s/step - loss: 1.7493 - acc: 0.5448 - val_loss: 2.5150 - val_acc: 0.4142
#
# Epoch 00004: val_loss improved from 2.62061 to 2.51500, saving model to /content/gdrive/My Drive/models/res22/res22mod_aug.h5
# Epoch 5/20
# 390/390 [==============================] - 487s 1s/step - loss: 1.7061 - acc: 0.5559 - val_loss: 2.5983 - val_acc: 0.4124
#
# Epoch 00005: val_loss did not improve from 2.51500
# Epoch 6/20
# 390/390 [==============================] - 487s 1s/step - loss: 1.6691 - acc: 0.5635 - val_loss: 2.6580 - val_acc: 0.4053
#
# Epoch 00006: val_loss did not improve from 2.51500
# Epoch 7/20
# 390/390 [==============================] - 486s 1s/step - loss: 1.6244 - acc: 0.5729 - val_loss: 2.4234 - val_acc: 0.4396
#
# Epoch 00007: val_loss improved from 2.51500 to 2.42342, saving model to /content/gdrive/My Drive/models/res22/res22mod_aug.h5
# Epoch 8/20
# 390/390 [==============================] - 486s 1s/step - loss: 1.5937 - acc: 0.5791 - val_loss: 2.5322 - val_acc: 0.4310
#
# Epoch 00008: val_loss did not improve from 2.42342
# Epoch 9/20
# 390/390 [==============================] - 487s 1s/step - loss: 1.5568 - acc: 0.5870 - val_loss: 2.5929 - val_acc: 0.4228
#
# Epoch 00009: val_loss did not improve from 2.42342
# Epoch 10/20
# 390/390 [==============================] - 486s 1s/step - loss: 1.5175 - acc: 0.5965 - val_loss: 2.6362 - val_acc: 0.4289
#
# Epoch 00010: val_loss did not improve from 2.42342
# Epoch 11/20
# 390/390 [==============================] - 486s 1s/step - loss: 1.4853 - acc: 0.6035 - val_loss: 2.4186 - val_acc: 0.4386
#
# Epoch 00011: val_loss improved from 2.42342 to 2.41857, saving model to /content/gdrive/My Drive/models/res22/res22mod_aug.h5
# Epoch 12/20
# 390/390 [==============================] - 487s 1s/step - loss: 1.4604 - acc: 0.6099 - val_loss: 2.4122 - val_acc: 0.4494
#
# Epoch 00012: val_loss improved from 2.41857 to 2.41216, saving model to /content/gdrive/My Drive/models/res22/res22mod_aug.h5
# Epoch 13/20
# 390/390 [==============================] - 488s 1s/step - loss: 1.4225 - acc: 0.6188 - val_loss: 2.4876 - val_acc: 0.4413
#
# Epoch 00013: val_loss did not improve from 2.41216
# Epoch 14/20
# 390/390 [==============================] - 487s 1s/step - loss: 1.3907 - acc: 0.6246 - val_loss: 2.6207 - val_acc: 0.4160
#
# Epoch 00014: val_loss did not improve from 2.41216
# Epoch 15/20
# 390/390 [==============================] - 487s 1s/step - loss: 1.3600 - acc: 0.6331 - val_loss: 2.4905 - val_acc: 0.4506
#
# Epoch 00015: val_loss did not improve from 2.41216
# Epoch 16/20
# 390/390 [==============================] - 486s 1s/step - loss: 1.3246 - acc: 0.6409 - val_loss: 2.4601 - val_acc: 0.4487
#
# Epoch 00016: val_loss did not improve from 2.41216
# Epoch 17/20
# 390/390 [==============================] - 486s 1s/step - loss: 1.3052 - acc: 0.6432 - val_loss: 2.5401 - val_acc: 0.4309
#
# Epoch 00017: val_loss did not improve from 2.41216
# Epoch 18/20
# 390/390 [==============================] - 487s 1s/step - loss: 1.2782 - acc: 0.6512 - val_loss: 2.5434 - val_acc: 0.4422
#
# Epoch 00018: val_loss did not improve from 2.41216
# Epoch 19/20
# 390/390 [==============================] - 488s 1s/step - loss: 1.2493 - acc: 0.6573 - val_loss: 2.4181 - val_acc: 0.4493
#
# Epoch 00019: val_loss did not improve from 2.41216
# Epoch 20/20
# 390/390 [==============================] - 488s 1s/step - loss: 1.2258 - acc: 0.6627 - val_loss: 2.5821 - val_acc: 0.4369
#
# Epoch 00020: val_loss did not improve from 2.41216
# model saved

# %% [markdown]
# # Epoch 76 - 95 : Intro CyclicLR
#
# ### Clearly visible that the local minima is changing to a different saddle point
#
# ### Quicker convergence noticed as promised by the paper

# %% [markdown]
# #Git clone

# %%
print('cloning repo...')
# !git clone https://github.com/bckenstler/CLR.git
print('clone complete')
# Out:
# cloning repo...
# Cloning into 'CLR'...
# remote: Enumerating objects: 244, done.
# remote: Total 244 (delta 0), reused 0 (delta 0), pack-reused 244
# Receiving objects: 100% (244/244), 1.37 MiB | 1.48 MiB/s, done.
# Resolving deltas: 100% (86/86), done.
# clone complete

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

print('loading model')
from keras.models import load_model
model = load_model('/content/gdrive/My Drive/models/res22/res22mod_aug.h5')
print('model loaded')

'''
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=3, min_lr=0.00099)
'''

from CLR import clr_callback
clr = clr_callback.CyclicLR(mode='triangular', step_size=1950,
                     base_lr=1e-4, max_lr=0.1)
checkpoints = ModelCheckpoint(filepath='/content/gdrive/My Drive/models/res22/res22mod_augCLR.h5', 
                               verbose=1,
                               save_weights_only=False,
                               save_best_only=True)

datagen = ImageDataGenerator(
        rescale=1./255,
        #shear_range=0.2,
        #zca_whitening=True,
        #featurewise_center=True,
        #samplewise_center=True,
        zoom_range=0.2,
        horizontal_flip=True,
        rotation_range=10,
        width_shift_range=0.2,
        height_shift_range=0.2
        )

train_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/train',
        target_size=(64,64),
        batch_size=256,
        class_mode='categorical')

validation_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/VAL_SELF',
        target_size=(64,64),
        batch_size=32,
        class_mode='categorical')

model.fit_generator(
        train_generator,
        steps_per_epoch=100000 // 256,
        epochs=20,
        #initial_epoch=0,
        callbacks=[clr, checkpoints],
        validation_data=validation_generator,
        validation_steps=10000//32)

plt.plot(clr.history['val_loss'], clr.history['lr'])

model.save('res22mod.h5')
model.save('/content/gdrive/My Drive/models/res22/res22mod_augCLR.h5')
print('model saved')
# Out:
# loading model
# model loaded
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# Epoch 1/20
# 390/390 [==============================] - 507s 1s/step - loss: 2.4218 - acc: 0.4118 - val_loss: 11.2192 - val_acc: 0.0349
#
# Epoch 00001: val_loss improved from inf to 11.21925, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR.h5
# Epoch 2/20
# 390/390 [==============================] - 495s 1s/step - loss: 2.8891 - acc: 0.3219 - val_loss: 12.9071 - val_acc: 0.0193
#
# Epoch 00002: val_loss did not improve from 11.21925
# Epoch 3/20
# 390/390 [==============================] - 492s 1s/step - loss: 2.9303 - acc: 0.3183 - val_loss: 7.6154 - val_acc: 0.0796
#
# Epoch 00003: val_loss improved from 11.21925 to 7.61545, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR.h5
# Epoch 4/20
# 390/390 [==============================] - 491s 1s/step - loss: 2.9828 - acc: 0.3069 - val_loss: 9.6192 - val_acc: 0.0547
#
# Epoch 00004: val_loss did not improve from 7.61545
# Epoch 5/20
# 390/390 [==============================] - 489s 1s/step - loss: 2.9937 - acc: 0.3067 - val_loss: 6.5527 - val_acc: 0.0996
#
# Epoch 00005: val_loss improved from 7.61545 to 6.55267, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR.h5
# Epoch 6/20
# 390/390 [==============================] - 489s 1s/step - loss: 2.8387 - acc: 0.3345 - val_loss: 4.1815 - val_acc: 0.2198
#
# Epoch 00006: val_loss improved from 6.55267 to 4.18149, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR.h5
# Epoch 7/20
# 390/390 [==============================] - 488s 1s/step - loss: 2.5616 - acc: 0.3846 - val_loss: 3.4777 - val_acc: 0.2751
#
# Epoch 00007: val_loss improved from 4.18149 to 3.47771, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR.h5
# Epoch 8/20
# 390/390 [==============================] - 487s 1s/step - loss: 2.3255 - acc: 0.4330 - val_loss: 2.9205 - val_acc: 0.3382
#
# Epoch 00008: val_loss improved from 3.47771 to 2.92053, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR.h5
# Epoch 9/20
# 390/390 [==============================] - 488s 1s/step - loss: 2.0840 - acc: 0.4810 - val_loss: 2.5104 - val_acc: 0.4154
#
# Epoch 00009: val_loss improved from 2.92053 to 2.51036, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR.h5
# Epoch 10/20
# 390/390 [==============================] - 489s 1s/step - loss: 1.8214 - acc: 0.5364 - val_loss: 2.0918 - val_acc: 0.4986
#
# Epoch 00010: val_loss improved from 2.51036 to 2.09181, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR.h5
# Epoch 11/20
# 390/390 [==============================] - 488s 1s/step - loss: 1.7461 - acc: 0.5531 - val_loss: 2.5304 - val_acc: 0.4193
#
# Epoch 00011: val_loss did not improve from 2.09181
# Epoch 12/20
# 390/390 [==============================] - 489s 1s/step - loss: 2.0504 - acc: 0.4887 - val_loss: 3.8499 - val_acc: 0.2734
#
# Epoch 00012: val_loss did not improve from 2.09181
# Epoch 13/20
# 390/390 [==============================] - 488s 1s/step - loss: 2.3299 - acc: 0.4316 - val_loss: 4.3465 - val_acc: 0.2084
#
# Epoch 00013: val_loss did not improve from 2.09181
# Epoch 14/20
# 390/390 [==============================] - 489s 1s/step - loss: 2.5095 - acc: 0.3950 - val_loss: 4.5507 - val_acc: 0.1824
#
# Epoch 00014: val_loss did not improve from 2.09181
# Epoch 15/20
# 390/390 [==============================] - 487s 1s/step - loss: 2.6273 - acc: 0.3754 - val_loss: 8.0559 - val_acc: 0.0639
#
# Epoch 00015: val_loss did not improve from 2.09181
# Epoch 16/20
# 390/390 [==============================] - 492s 1s/step - loss: 2.5514 - acc: 0.3901 - val_loss: 3.2864 - val_acc: 0.3056
#
# Epoch 00016: val_loss did not improve from 2.09181
# Epoch 17/20
# 390/390 [==============================] - 495s 1s/step - loss: 2.3238 - acc: 0.4339 - val_loss: 3.2367 - val_acc: 0.3160
#
# Epoch 00017: val_loss did not improve from 2.09181
# Epoch 18/20
# 390/390 [==============================] - 491s 1s/step - loss: 2.1007 - acc: 0.4799 - val_loss: 2.6533 - val_acc: 0.4090
#
# Epoch 00018: val_loss did not improve from 2.09181
# Epoch 19/20
# 390/390 [==============================] - 491s 1s/step - loss: 1.8703 - acc: 0.5292 - val_loss: 2.3056 - val_acc: 0.4545
#
# Epoch 00019: val_loss did not improve from 2.09181
# Epoch 20/20
# 390/390 [==============================] - 490s 1s/step - loss: 1.6312 - acc: 0.5793 - val_loss: 2.0614 - val_acc: 0.5113
#
# Epoch 00020: val_loss improved from 2.09181 to 2.06135, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR.h5
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-92d32a8be731> in <module>()
#      58         validation_steps=10000//32)
#      59
# ---> 60 plt.plot(clr.history['val_loss'], clr.history['lr'])
#      61
#      62 model.save('res22mod.h5')
#
# KeyError: 'val_loss'

# %% [markdown]
# #Epoch 95 - 105 : Refining CLR : finding lr_base and lr_max

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

print('loading model')
from keras.models import load_model
model = load_model('/content/gdrive/My Drive/models/res22/res22mod_augCLR.h5')
print('model loaded')

'''
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=3, min_lr=0.00099)
'''
from CLR import clr_callback
clr = clr_callback.CyclicLR(mode='triangular', step_size=1560,
                     base_lr=1e-4, max_lr=0.1)
checkpoints = ModelCheckpoint(filepath='/content/gdrive/My Drive/models/res22/res22mod_augCLR_.h5', 
                               verbose=1,
                               save_weights_only=False,
                               save_best_only=True)

datagen = ImageDataGenerator(
        rescale=1./255,
        #shear_range=0.2,
        #zca_whitening=True,
        #featurewise_center=True,
        #samplewise_center=True,
        zoom_range=0.2,
        horizontal_flip=True,
        rotation_range=10,
        width_shift_range=0.2,
        height_shift_range=0.2
        )

train_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/train',
        target_size=(64,64),
        batch_size=256,
        class_mode='categorical')

validation_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/VAL_SELF',
        target_size=(64,64),
        batch_size=32,
        class_mode='categorical')

model_history = model.fit_generator(
                    train_generator,
                    steps_per_epoch=100000 // 256,
                    epochs=40,
                    #initial_epoch=0,
                    callbacks=[clr, checkpoints],
                    validation_data=validation_generator,
                    validation_steps=10000//32)

hist = clr.history # keys: acc, batch, iterations, loss(val or train??), lr, size(train batch_size)
lr = hist['lr']
val_loss = hist['loss']
Iter = hist['iterations']
plt.plot(lr, val_loss)
#plt.plot(Iter, val_loss)
plt.show()

model.save('res22mod.h5')
model.save('/content/gdrive/My Drive/models/res22/res22mod_augCLR_.h5')
print('model saved')
# Out:
# loading model
# model loaded
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# Epoch 1/40
# 390/390 [==============================] - 484s 1s/step - loss: 1.5825 - acc: 0.5893 - val_loss: 2.4623 - val_acc: 0.4396
#
# Epoch 00001: val_loss improved from inf to 2.46226, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR_.h5
# Epoch 2/40
# 390/390 [==============================] - 481s 1s/step - loss: 1.8590 - acc: 0.5274 - val_loss: 2.9708 - val_acc: 0.3653
#
# Epoch 00002: val_loss did not improve from 2.46226
# Epoch 3/40
# 390/390 [==============================] - 476s 1s/step - loss: 2.1353 - acc: 0.4720 - val_loss: 4.0243 - val_acc: 0.2468
#
# Epoch 00003: val_loss did not improve from 2.46226
# Epoch 4/40
# 390/390 [==============================] - 476s 1s/step - loss: 2.3558 - acc: 0.4285 - val_loss: 4.1370 - val_acc: 0.2030
#
# Epoch 00004: val_loss did not improve from 2.46226
# Epoch 5/40
# 390/390 [==============================] - 475s 1s/step - loss: 2.3139 - acc: 0.4370 - val_loss: 3.1435 - val_acc: 0.3261
#
# Epoch 00005: val_loss did not improve from 2.46226
# Epoch 6/40
# 390/390 [==============================] - 475s 1s/step - loss: 2.0414 - acc: 0.4918 - val_loss: 2.7637 - val_acc: 0.3877
#
# Epoch 00006: val_loss did not improve from 2.46226
# Epoch 7/40
# 390/390 [==============================] - 475s 1s/step - loss: 1.7810 - acc: 0.5482 - val_loss: 2.2761 - val_acc: 0.4676
#
# Epoch 00007: val_loss improved from 2.46226 to 2.27614, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR_.h5
# Epoch 8/40
# 390/390 [==============================] - 476s 1s/step - loss: 1.5206 - acc: 0.6028 - val_loss: 2.0728 - val_acc: 0.5173
#
# Epoch 00008: val_loss improved from 2.27614 to 2.07281, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR_.h5
# Epoch 9/40
# 390/390 [==============================] - 476s 1s/step - loss: 1.4558 - acc: 0.6177 - val_loss: 2.2861 - val_acc: 0.4765
#
# Epoch 00009: val_loss did not improve from 2.07281
# Epoch 10/40
# 390/390 [==============================] - 475s 1s/step - loss: 1.6602 - acc: 0.5699 - val_loss: 2.8091 - val_acc: 0.4017
#
# Epoch 00010: val_loss did not improve from 2.07281
# Epoch 11/40
# 390/390 [==============================] - 476s 1s/step - loss: 1.9051 - acc: 0.5189 - val_loss: 3.2528 - val_acc: 0.3280
#
# Epoch 00011: val_loss did not improve from 2.07281
# Epoch 12/40
# 390/390 [==============================] - 476s 1s/step - loss: 2.0967 - acc: 0.4793 - val_loss: 3.9271 - val_acc: 0.3095
#
# Epoch 00012: val_loss did not improve from 2.07281
# Epoch 13/40
# 390/390 [==============================] - 476s 1s/step - loss: 2.0859 - acc: 0.4839 - val_loss: 2.8410 - val_acc: 0.3691
#
# Epoch 00013: val_loss did not improve from 2.07281
# Epoch 14/40
# 390/390 [==============================] - 476s 1s/step - loss: 1.8320 - acc: 0.5360 - val_loss: 2.5904 - val_acc: 0.4217
#
# Epoch 00014: val_loss did not improve from 2.07281
# Epoch 15/40
# 390/390 [==============================] - 475s 1s/step - loss: 1.5946 - acc: 0.5856 - val_loss: 2.2549 - val_acc: 0.4912
#
# Epoch 00015: val_loss did not improve from 2.07281
# Epoch 16/40
# 390/390 [==============================] - 476s 1s/step - loss: 1.3620 - acc: 0.6393 - val_loss: 2.0571 - val_acc: 0.5219
#
# Epoch 00016: val_loss improved from 2.07281 to 2.05708, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR_.h5
# Epoch 17/40
# 390/390 [==============================] - 474s 1s/step - loss: 1.2979 - acc: 0.6552 - val_loss: 2.3086 - val_acc: 0.4853
#
# Epoch 00017: val_loss did not improve from 2.05708
# Epoch 18/40
# 390/390 [==============================] - 475s 1s/step - loss: 1.4706 - acc: 0.6143 - val_loss: 2.6213 - val_acc: 0.4102
#
# Epoch 00018: val_loss did not improve from 2.05708
# Epoch 19/40
# 390/390 [==============================] - 475s 1s/step - loss: 1.6831 - acc: 0.5662 - val_loss: 2.8429 - val_acc: 0.3937
#
# Epoch 00019: val_loss did not improve from 2.05708
# Epoch 20/40
# 390/390 [==============================] - 476s 1s/step - loss: 1.8894 - acc: 0.5247 - val_loss: 3.2490 - val_acc: 0.3471
#
# Epoch 00020: val_loss did not improve from 2.05708
# Epoch 21/40
# 390/390 [==============================] - 475s 1s/step - loss: 1.8907 - acc: 0.5235 - val_loss: 2.8058 - val_acc: 0.3998
#
# Epoch 00021: val_loss did not improve from 2.05708
# Epoch 22/40
# 390/390 [==============================] - 472s 1s/step - loss: 1.6532 - acc: 0.5737 - val_loss: 2.3721 - val_acc: 0.4620
#
# Epoch 00022: val_loss did not improve from 2.05708
# Epoch 23/40
# 390/390 [==============================] - 472s 1s/step - loss: 1.4253 - acc: 0.6247 - val_loss: 2.1906 - val_acc: 0.4963
#
# Epoch 00023: val_loss did not improve from 2.05708
# Epoch 24/40
# 390/390 [==============================] - 471s 1s/step - loss: 1.2025 - acc: 0.6767 - val_loss: 2.0536 - val_acc: 0.5302
#
# Epoch 00024: val_loss improved from 2.05708 to 2.05360, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR_.h5
# Epoch 25/40
# 390/390 [==============================] - 471s 1s/step - loss: 1.1462 - acc: 0.6899 - val_loss: 2.2412 - val_acc: 0.5014
#
# Epoch 00025: val_loss did not improve from 2.05360
# Epoch 26/40
# 390/390 [==============================] - 471s 1s/step - loss: 1.3100 - acc: 0.6485 - val_loss: 2.5751 - val_acc: 0.4375
#
# Epoch 00026: val_loss did not improve from 2.05360
# Epoch 27/40
# 390/390 [==============================] - 471s 1s/step - loss: 1.5092 - acc: 0.6016 - val_loss: 3.1411 - val_acc: 0.3765
#
# Epoch 00027: val_loss did not improve from 2.05360
# Epoch 28/40
# 390/390 [==============================] - 472s 1s/step - loss: 1.7084 - acc: 0.5608 - val_loss: 4.1443 - val_acc: 0.3064
#
# Epoch 00028: val_loss did not improve from 2.05360
# Epoch 29/40
# 390/390 [==============================] - 472s 1s/step - loss: 1.7128 - acc: 0.5585 - val_loss: 2.7448 - val_acc: 0.4089
#
# Epoch 00029: val_loss did not improve from 2.05360
# Epoch 30/40
# 390/390 [==============================] - 471s 1s/step - loss: 1.4967 - acc: 0.6072 - val_loss: 2.4256 - val_acc: 0.4642
#
# Epoch 00030: val_loss did not improve from 2.05360
# Epoch 31/40
# 390/390 [==============================] - 473s 1s/step - loss: 1.2852 - acc: 0.6573 - val_loss: 2.1725 - val_acc: 0.5092
#
# Epoch 00031: val_loss did not improve from 2.05360
# Epoch 32/40
# 390/390 [==============================] - 472s 1s/step - loss: 1.0724 - acc: 0.7061 - val_loss: 2.1522 - val_acc: 0.5270
#
# Epoch 00032: val_loss did not improve from 2.05360
# Epoch 33/40
# 390/390 [==============================] - 473s 1s/step - loss: 1.0250 - acc: 0.7173 - val_loss: 2.3470 - val_acc: 0.5109
#
# Epoch 00033: val_loss did not improve from 2.05360
# Epoch 34/40
# 390/390 [==============================] - 472s 1s/step - loss: 1.1709 - acc: 0.6805 - val_loss: 2.4765 - val_acc: 0.4715
#
# Epoch 00034: val_loss did not improve from 2.05360
# Epoch 35/40
# 390/390 [==============================] - 471s 1s/step - loss: 1.3709 - acc: 0.6348 - val_loss: 2.8631 - val_acc: 0.4257
#
# Epoch 00035: val_loss did not improve from 2.05360
# Epoch 36/40
# 390/390 [==============================] - 472s 1s/step - loss: 1.5659 - acc: 0.5907 - val_loss: 3.3237 - val_acc: 0.3622
#
# Epoch 00036: val_loss did not improve from 2.05360
# Epoch 37/40
# 390/390 [==============================] - 471s 1s/step - loss: 1.5736 - acc: 0.5885 - val_loss: 2.5390 - val_acc: 0.4500
#
# Epoch 00037: val_loss did not improve from 2.05360
# Epoch 38/40
# 390/390 [==============================] - 471s 1s/step - loss: 1.3671 - acc: 0.6346 - val_loss: 2.4912 - val_acc: 0.4776
#
# Epoch 00038: val_loss did not improve from 2.05360
# Epoch 39/40
# 390/390 [==============================] - 471s 1s/step - loss: 1.1537 - acc: 0.6847 - val_loss: 2.2706 - val_acc: 0.5055
#
# Epoch 00039: val_loss did not improve from 2.05360
# Epoch 40/40
# 390/390 [==============================] - 472s 1s/step - loss: 0.9635 - acc: 0.7319 - val_loss: 2.2027 - val_acc: 0.5356
#
# Epoch 00040: val_loss did not improve from 2.05360
# model saved

# %%
from google.colab import files
plt.savefig('Loss_vs_LR.PNG')
files.download('Loss_vs_LR.PNG')

# %%
plt.plot(Iter, lr)
plt.show(Iter, lr)
from google.colab import files
plt.savefig('Iter_vs_LR.PNG')
files.download('Iter_vs_LR.PNG')

# %%
plt.plot(Iter, hist['acc'])
plt.show(Iter, hist['acc'])
from google.colab import files
plt.savefig('Acc_vs_Iter.PNG')
files.download('Acc_vs_Iter.PNG')

# %% [markdown]
# #Epoch 106 - 125 : fill_mode

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

print('loading model')
from keras.models import load_model
model = load_model('/content/gdrive/My Drive/models/res22/res22mod_augCLR_.h5')
print('model loaded')

'''
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=3, min_lr=0.00099)
'''
from CLR import clr_callback
clr = clr_callback.CyclicLR(mode='triangular', step_size=1560,
                     base_lr=1e-4, max_lr=0.1)
checkpoints = ModelCheckpoint(filepath='/content/gdrive/My Drive/models/res22/res22mod_augCLR_fill_mode.h5', 
                               verbose=1,
                               save_weights_only=False,
                               save_best_only=True)

datagen = ImageDataGenerator(
        rescale=1./255,
        #shear_range=0.2,
        #zca_whitening=True,
        #featurewise_center=True,
        #samplewise_center=True,
        zoom_range=0.2,
        horizontal_flip=True,
        rotation_range=10,
        width_shift_range=0.2,
        height_shift_range=0.2,
        fill_mode='nearest'
        )

train_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/train',
        target_size=(64,64),
        batch_size=256,
        class_mode='categorical')

validation_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/VAL_SELF',
        target_size=(64,64),
        batch_size=32,
        class_mode='categorical')

model_history = model.fit_generator(
                    train_generator,
                    steps_per_epoch=100000 // 256,
                    epochs=20,
                    #initial_epoch=0,
                    callbacks=[clr, checkpoints],
                    validation_data=validation_generator,
                    validation_steps=10000//32)

hist = clr.history # keys: acc, batch, iterations, loss(val or train??), lr, size(train batch_size)
lr = hist['lr']
val_loss = hist['loss']
Iter = hist['iterations']
plt.plot(lr, val_loss)
#plt.plot(Iter, val_loss)
plt.show()

model.save('res22mod.h5')
model.save('/content/gdrive/My Drive/models/res22/res22mod_augCLR_fill_mode.h5')
print('model saved')
# Out:
# loading model
# model loaded
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# Epoch 1/20
# 390/390 [==============================] - 505s 1s/step - loss: 0.9021 - acc: 0.7486 - val_loss: 2.3355 - val_acc: 0.5061
#
# Epoch 00001: val_loss improved from inf to 2.33554, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR_fill_mode.h5
# Epoch 2/20
# 390/390 [==============================] - 502s 1s/step - loss: 1.0477 - acc: 0.7109 - val_loss: 2.6218 - val_acc: 0.4729
#
# Epoch 00002: val_loss did not improve from 2.33554
# Epoch 3/20
# 390/390 [==============================] - 496s 1s/step - loss: 1.2478 - acc: 0.6622 - val_loss: 2.8573 - val_acc: 0.4291
#
# Epoch 00003: val_loss did not improve from 2.33554
# Epoch 4/20
# 390/390 [==============================] - 495s 1s/step - loss: 1.4541 - acc: 0.6133 - val_loss: 3.3412 - val_acc: 0.3634
#
# Epoch 00004: val_loss did not improve from 2.33554
# Epoch 5/20
# 390/390 [==============================] - 496s 1s/step - loss: 1.4680 - acc: 0.6119 - val_loss: 2.5332 - val_acc: 0.4579
#
# Epoch 00005: val_loss did not improve from 2.33554
# Epoch 6/20
# 390/390 [==============================] - 495s 1s/step - loss: 1.2679 - acc: 0.6570 - val_loss: 2.3833 - val_acc: 0.4864
#
# Epoch 00006: val_loss did not improve from 2.33554
# Epoch 7/20
# 390/390 [==============================] - 495s 1s/step - loss: 1.0461 - acc: 0.7101 - val_loss: 2.3132 - val_acc: 0.5126
#
# Epoch 00007: val_loss improved from 2.33554 to 2.31317, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR_fill_mode.h5
# Epoch 8/20
# 390/390 [==============================] - 497s 1s/step - loss: 0.8593 - acc: 0.7587 - val_loss: 2.2880 - val_acc: 0.5316
#
# Epoch 00008: val_loss improved from 2.31317 to 2.28795, saving model to /content/gdrive/My Drive/models/res22/res22mod_augCLR_fill_mode.h5
# Epoch 9/20
# 390/390 [==============================] - 497s 1s/step - loss: 0.8113 - acc: 0.7710 - val_loss: 2.3877 - val_acc: 0.5128
#
# Epoch 00009: val_loss did not improve from 2.28795
# Epoch 10/20
# 390/390 [==============================] - 496s 1s/step - loss: 0.9418 - acc: 0.7357 - val_loss: 2.6877 - val_acc: 0.4638
#
# Epoch 00010: val_loss did not improve from 2.28795
# Epoch 11/20
# 390/390 [==============================] - 495s 1s/step - loss: 1.1520 - acc: 0.6840 - val_loss: 2.9273 - val_acc: 0.4411
#
# Epoch 00011: val_loss did not improve from 2.28795
# Epoch 12/20
# 390/390 [==============================] - 494s 1s/step - loss: 1.3346 - acc: 0.6393 - val_loss: 3.5560 - val_acc: 0.3733
#
# Epoch 00012: val_loss did not improve from 2.28795
# Epoch 13/20
# 390/390 [==============================] - 495s 1s/step - loss: 1.3599 - acc: 0.6350 - val_loss: 2.7272 - val_acc: 0.4457
#
# Epoch 00013: val_loss did not improve from 2.28795
# Epoch 14/20
# 390/390 [==============================] - 495s 1s/step - loss: 1.1525 - acc: 0.6850 - val_loss: 2.5784 - val_acc: 0.4793
#
# Epoch 00014: val_loss did not improve from 2.28795
# Epoch 15/20
# 390/390 [==============================] - 497s 1s/step - loss: 0.9548 - acc: 0.7329 - val_loss: 2.4671 - val_acc: 0.5119
#
# Epoch 00015: val_loss did not improve from 2.28795
# Epoch 16/20
# 390/390 [==============================] - 496s 1s/step - loss: 0.7720 - acc: 0.7811 - val_loss: 2.3908 - val_acc: 0.5323
#
# Epoch 00016: val_loss did not improve from 2.28795
# Epoch 17/20
# 390/390 [==============================] - 495s 1s/step - loss: 0.7245 - acc: 0.7934 - val_loss: 2.5061 - val_acc: 0.5085
#
# Epoch 00017: val_loss did not improve from 2.28795
# Epoch 18/20
# 390/390 [==============================] - 491s 1s/step - loss: 0.8489 - acc: 0.7589 - val_loss: 2.7336 - val_acc: 0.4741
#
# Epoch 00018: val_loss did not improve from 2.28795
# Epoch 19/20
# 390/390 [==============================] - 496s 1s/step - loss: 1.0463 - acc: 0.7104 - val_loss: 3.0764 - val_acc: 0.4431
#
# Epoch 00019: val_loss did not improve from 2.28795
# Epoch 20/20
# 390/390 [==============================] - 497s 1s/step - loss: 1.2497 - acc: 0.6597 - val_loss: 3.0902 - val_acc: 0.4170
#
# Epoch 00020: val_loss did not improve from 2.28795
# model saved

# %%
plt.plot(clr.history['iterations'], clr.history['lr'])

# %%
plt.plot(clr.history['lr'], clr.history['acc'])

# %% [markdown]
# #Epoch 126 - 160 : Pushing the accuracies to max limit/ saturation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

print('loading model')
from keras.models import load_model
model = load_model('/content/gdrive/My Drive/models/res22/res22mod_augCLR_fill_mode.h5')
print('model loaded')

'''
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=3, min_lr=0.00099)
'''
from CLR import clr_callback
clr = clr_callback.CyclicLR(mode='triangular', step_size=1560,
                     base_lr=1e-4, max_lr=0.1)
checkpoints = ModelCheckpoint(filepath='/content/gdrive/My Drive/models/res22/res22_final.h5', 
                               verbose=1,
                               save_weights_only=False,
                               save_best_only=True)

datagen = ImageDataGenerator(
        rescale=1./255,
        #shear_range=0.2,
        #zca_whitening=True,
        #featurewise_center=True,
        #samplewise_center=True,
        zoom_range=0.2,
        horizontal_flip=True,
        rotation_range=10,
        width_shift_range=0.2,
        height_shift_range=0.2
        )

train_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/train',
        target_size=(64,64),
        batch_size=256,
        class_mode='categorical')

validation_generator = datagen.flow_from_directory(
        '/content/tiny-imagenet-200/VAL_SELF',
        target_size=(64,64),
        batch_size=32,
        class_mode='categorical')

model_history = model.fit_generator(
                    train_generator,
                    steps_per_epoch=100000 // 256,
                    epochs=40,
                    #initial_epoch=0,
                    callbacks=[clr, checkpoints],
                    validation_data=validation_generator,
                    validation_steps=10000//32)

hist = clr.history # keys: acc, batch, iterations, loss(val or train??), lr, size(train batch_size)
lr = hist['lr']
val_loss = hist['loss']
Iter = hist['iterations']
plt.plot(lr, val_loss)
#plt.plot(Iter, val_loss)
plt.show()

#model.save('res22mod.h5')
model.save('/content/gdrive/My Drive/models/res22/res22_final.h5')
print('model saved')
# Out:
# loading model
# model loaded
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# Epoch 1/40
# 390/390 [==============================] - 491s 1s/step - loss: 0.9411 - acc: 0.7360 - val_loss: 2.4382 - val_acc: 0.5154
#
# Epoch 00001: val_loss improved from inf to 2.43816, saving model to /content/gdrive/My Drive/models/res22/res22_final.h5
# Epoch 2/40
# 390/390 [==============================] - 488s 1s/step - loss: 0.8717 - acc: 0.7540 - val_loss: 2.8414 - val_acc: 0.4694
#
# Epoch 00002: val_loss did not improve from 2.43816
# Epoch 3/40
# 390/390 [==============================] - 484s 1s/step - loss: 1.0106 - acc: 0.7182 - val_loss: 3.1440 - val_acc: 0.4224
#
# Epoch 00003: val_loss did not improve from 2.43816
# Epoch 4/40
# 390/390 [==============================] - 484s 1s/step - loss: 1.2037 - acc: 0.6707 - val_loss: 3.1740 - val_acc: 0.4076
#
# Epoch 00004: val_loss did not improve from 2.43816
# Epoch 5/40
# 390/390 [==============================] - 481s 1s/step - loss: 1.2372 - acc: 0.6644 - val_loss: 2.7126 - val_acc: 0.4525
#
# Epoch 00005: val_loss did not improve from 2.43816
# Epoch 6/40
# 390/390 [==============================] - 489s 1s/step - loss: 1.0263 - acc: 0.7158 - val_loss: 2.5879 - val_acc: 0.4873
#
# Epoch 00006: val_loss did not improve from 2.43816
# Epoch 7/40
# 390/390 [==============================] - 489s 1s/step - loss: 0.8310 - acc: 0.7647 - val_loss: 2.5549 - val_acc: 0.5075
#
# Epoch 00007: val_loss did not improve from 2.43816
# Epoch 8/40
# 390/390 [==============================] - 491s 1s/step - loss: 0.6548 - acc: 0.8114 - val_loss: 2.4986 - val_acc: 0.5353
#
# Epoch 00008: val_loss did not improve from 2.43816
# Epoch 9/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.6167 - acc: 0.8219 - val_loss: 2.6534 - val_acc: 0.5200
#
# Epoch 00009: val_loss did not improve from 2.43816
# Epoch 10/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.7433 - acc: 0.7860 - val_loss: 2.8044 - val_acc: 0.4827
#
# Epoch 00010: val_loss did not improve from 2.43816
# Epoch 11/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.9211 - acc: 0.7394 - val_loss: 3.2283 - val_acc: 0.4427
#
# Epoch 00011: val_loss did not improve from 2.43816
# Epoch 12/40
# 390/390 [==============================] - 490s 1s/step - loss: 1.1404 - acc: 0.6874 - val_loss: 3.1274 - val_acc: 0.4138
#
# Epoch 00012: val_loss did not improve from 2.43816
# Epoch 13/40
# 390/390 [==============================] - 491s 1s/step - loss: 1.1657 - acc: 0.6802 - val_loss: 2.7212 - val_acc: 0.4607
#
# Epoch 00013: val_loss did not improve from 2.43816
# Epoch 14/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.9427 - acc: 0.7342 - val_loss: 2.7249 - val_acc: 0.4874
#
# Epoch 00014: val_loss did not improve from 2.43816
# Epoch 15/40
# 390/390 [==============================] - 489s 1s/step - loss: 0.7591 - acc: 0.7825 - val_loss: 2.5785 - val_acc: 0.5112
#
# Epoch 00015: val_loss did not improve from 2.43816
# Epoch 16/40
# 390/390 [==============================] - 489s 1s/step - loss: 0.5908 - acc: 0.8270 - val_loss: 2.6251 - val_acc: 0.5302
#
# Epoch 00016: val_loss did not improve from 2.43816
# Epoch 17/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.5525 - acc: 0.8375 - val_loss: 2.8142 - val_acc: 0.5083
#
# Epoch 00017: val_loss did not improve from 2.43816
# Epoch 18/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.6735 - acc: 0.8050 - val_loss: 2.8071 - val_acc: 0.4780
#
# Epoch 00018: val_loss did not improve from 2.43816
# Epoch 19/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.8528 - acc: 0.7565 - val_loss: 2.9327 - val_acc: 0.4400
#
# Epoch 00019: val_loss did not improve from 2.43816
# Epoch 20/40
# 390/390 [==============================] - 490s 1s/step - loss: 1.0467 - acc: 0.7078 - val_loss: 3.2186 - val_acc: 0.4311
#
# Epoch 00020: val_loss did not improve from 2.43816
# Epoch 21/40
# 390/390 [==============================] - 490s 1s/step - loss: 1.0838 - acc: 0.6997 - val_loss: 2.8110 - val_acc: 0.4734
#
# Epoch 00021: val_loss did not improve from 2.43816
# Epoch 22/40
# 390/390 [==============================] - 491s 1s/step - loss: 0.8805 - acc: 0.7493 - val_loss: 2.7838 - val_acc: 0.4826
#
# Epoch 00022: val_loss did not improve from 2.43816
# Epoch 23/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.6894 - acc: 0.8006 - val_loss: 2.7679 - val_acc: 0.5085
#
# Epoch 00023: val_loss did not improve from 2.43816
# Epoch 24/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.5363 - acc: 0.8414 - val_loss: 2.6886 - val_acc: 0.5279
#
# Epoch 00024: val_loss did not improve from 2.43816
# Epoch 25/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.4948 - acc: 0.8543 - val_loss: 2.8280 - val_acc: 0.5149
#
# Epoch 00025: val_loss did not improve from 2.43816
# Epoch 26/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.6084 - acc: 0.8211 - val_loss: 3.1102 - val_acc: 0.4805
#
# Epoch 00026: val_loss did not improve from 2.43816
# Epoch 27/40
# 390/390 [==============================] - 489s 1s/step - loss: 0.7906 - acc: 0.7730 - val_loss: 3.1483 - val_acc: 0.4472
#
# Epoch 00027: val_loss did not improve from 2.43816
# Epoch 28/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.9917 - acc: 0.7215 - val_loss: 3.3436 - val_acc: 0.4278
#
# Epoch 00028: val_loss did not improve from 2.43816
# Epoch 29/40
# 390/390 [==============================] - 490s 1s/step - loss: 1.0102 - acc: 0.7176 - val_loss: 2.8875 - val_acc: 0.4767
#
# Epoch 00029: val_loss did not improve from 2.43816
# Epoch 30/40
# 390/390 [==============================] - 491s 1s/step - loss: 0.8173 - acc: 0.7662 - val_loss: 2.7205 - val_acc: 0.4955
#
# Epoch 00030: val_loss did not improve from 2.43816
# Epoch 31/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.6367 - acc: 0.8129 - val_loss: 2.8055 - val_acc: 0.5110
#
# Epoch 00031: val_loss did not improve from 2.43816
# Epoch 32/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.4861 - acc: 0.8551 - val_loss: 2.7434 - val_acc: 0.5346
#
# Epoch 00032: val_loss did not improve from 2.43816
# Epoch 33/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.4467 - acc: 0.8662 - val_loss: 2.9290 - val_acc: 0.5162
#
# Epoch 00033: val_loss did not improve from 2.43816
# Epoch 34/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.5586 - acc: 0.8347 - val_loss: 3.2001 - val_acc: 0.4830
#
# Epoch 00034: val_loss did not improve from 2.43816
# Epoch 35/40
# 390/390 [==============================] - 490s 1s/step - loss: 0.7893 - acc: 0.7735 - val_loss: 3.1143 - val_acc: 0.4477
#
# Epoch 00035: val_loss did not improve from 2.43816
# Epoch 36/40
# 390/390 [==============================] - 491s 1s/step - loss: 0.9167 - acc: 0.7412 - val_loss: 3.2751 - val_acc: 0.4322
#
# Epoch 00036: val_loss did not improve from 2.43816
# Epoch 37/40
# 390/390 [==============================] - 485s 1s/step - loss: 0.9532 - acc: 0.7327 - val_loss: 3.1334 - val_acc: 0.4609
#
# Epoch 00037: val_loss did not improve from 2.43816
# Epoch 38/40
# 390/390 [==============================] - 484s 1s/step - loss: 0.7612 - acc: 0.7812 - val_loss: 2.9076 - val_acc: 0.4871
#
# Epoch 00038: val_loss did not improve from 2.43816
# Epoch 39/40
# 390/390 [==============================] - 485s 1s/step - loss: 0.5851 - acc: 0.8284 - val_loss: 2.8869 - val_acc: 0.5140
#
# Epoch 00039: val_loss did not improve from 2.43816
# Epoch 40/40
# 390/390 [==============================] - 484s 1s/step - loss: 0.4447 - acc: 0.8669 - val_loss: 2.8556 - val_acc: 0.5239
#
# Epoch 00040: val_loss did not improve from 2.43816
# model saved
